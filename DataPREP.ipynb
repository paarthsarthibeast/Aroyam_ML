# %% [markdown]
# # DATA PREPROCESSING

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import warnings
warnings.filterwarnings("ignore")

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve

# %%
admissions = pd.read_csv('admissions_202208161605.csv')
patients = pd.read_csv('patients_202208161605.csv')
diagnoses = pd.read_csv('diagnoses_icd_202208161605.csv')
procedures=pd.read_csv('procedures_icd_202208161605.csv')
labevents=pd.read_csv('labevents_202208161605.csv')
cptevents=pd.read_csv('cptevents_202208161605.csv')
drgcodes=pd.read_csv('drgcodes_202208161605.csv')

# %%
print(drgcodes.isnull().sum())
# Out:
# row_id               0
# subject_id           0
# hadm_id              0
# drg_type             0
# drg_code             0
# description         63
# drg_severity     58923
# drg_mortality    58923
# dtype: int64

# %%
# admissions=admissions.dropna()
# patients=patients.dropna()
# diagnoses=diagnoses.dropna()

# %%
# admit_counts = admissions['subject_id'].value_counts()
# print(admit_counts.describe())
# print(admit_counts.value_counts().sort_index())
print(admissions.shape)
print(patients.shape)
total_rows = len(admissions)
unique_subjects = admissions['subject_id'].nunique()

print(f"Total rows in cohort: {total_rows}")
print(f"Unique subject_ids: {unique_subjects}")

# Check for duplicates
duplicate_subjects = admissions['subject_id'].duplicated().sum()
print(f"Number of duplicate subject_id entries: {duplicate_subjects}")
# Out:
# (58976, 19)
# (46520, 8)
# Total rows in cohort: 58976
# Unique subject_ids: 46520
# Number of duplicate subject_id entries: 12456

# %%
hf_icd9 = [
    '39891','40201','40211','40291','40401','40403','40411','40413','40491','40493',
    '4280','4281','42820','42821','42822','42823','42830','42831','42832',
    '42833','42840','42841','42842','42843','4289'
]

# %%
#drop row id
diagnoses = diagnoses.drop(columns=['row_id'])
admissions = admissions.drop(columns=['row_id'])
procedures = procedures.drop(columns=['row_id'])
patients = patients.drop(columns=['row_id'])
labevents = labevents.drop(columns=['row_id'])
cptevents = cptevents.drop(columns=['row_id'])
drgcodes = drgcodes.drop(columns=['row_id'])

hf_diagnoses = diagnoses[diagnoses['icd9_code'].astype(str).isin(hf_icd9)]
hf_admissions = admissions[admissions['hadm_id'].isin(hf_diagnoses['hadm_id'])].copy()

# %%
# 3. Merge with patient demographic data
hf_cohort = hf_admissions.merge(patients[['subject_id', 'dob', 'gender']], on='subject_id', how='left')
hf_cohort = hf_cohort.merge(hf_diagnoses, on=['subject_id', 'hadm_id'], how='left')

# Merge with lab events to get lab test results
hf_labevents = labevents[labevents['hadm_id'].isin(hf_cohort['hadm_id'])]
# Average lab value (for numeric values)
lab_avg = hf_labevents.groupby('hadm_id')['valuenum'].mean().reset_index(name='avg_lab_value')
hf_cohort = hf_cohort.merge(lab_avg[['hadm_id', 'avg_lab_value']], on='hadm_id', how='left')

# Merge with cpt codes to count the number of procedures
hf_cptevents = cptevents[cptevents['hadm_id'].isin(hf_cohort['hadm_id'])]
cpt_code_count = hf_cptevents.groupby('hadm_id')['cpt_cd'].nunique().reset_index(name='cpt_code_count')
hf_cohort = hf_cohort.merge(cpt_code_count[['hadm_id', 'cpt_code_count']], on='hadm_id', how='left')

# Merge with DRG codes for severity
hf_drgcodes = drgcodes[drgcodes['hadm_id'].isin(hf_cohort['hadm_id'])]
drg_severity = hf_drgcodes[['hadm_id', 'drg_severity']].drop_duplicates()
hf_cohort = hf_cohort.merge(drg_severity, on='hadm_id', how='left')



hf_cohort['ethnicity_group'] = hf_cohort['ethnicity'].apply(lambda x: 'Non-Caucasian' if x != 'Caucasian' else 'Caucasian')

# Check how many unique subject_ids vs total rows
total_rows = len(hf_cohort)
print(hf_cohort)
unique_subjects = hf_cohort['subject_id'].nunique()

print(f"Total rows in cohort: {total_rows}")
print(f"Unique subject_ids: {unique_subjects}")

# Check for duplicates
duplicate_subjects = hf_cohort['subject_id'].duplicated().sum()
print(f"Number of duplicate subject_id entries: {duplicate_subjects}")
# Out:
#        subject_id  hadm_id                admittime                dischtime  \
# 0              26   197661  2126-05-06 15:16:00.000  2126-05-13 15:00:00.000
# 1              30   104557  2172-10-14 14:17:00.000  2172-10-19 14:37:00.000
# 2              34   115799  2186-07-18 16:46:00.000  2186-07-20 16:00:00.000
# 3              34   115799  2186-07-18 16:46:00.000  2186-07-20 16:00:00.000
# 4              34   144319  2191-02-23 05:23:00.000  2191-02-25 20:20:00.000
# ...           ...      ...                      ...                      ...
# 38233       98753   185764  2172-02-11 21:26:00.000  2172-03-02 08:00:00.000
# 38234       98755   184156  2167-05-17 12:36:00.000  2167-05-18 17:03:00.000
# 38235       98755   184156  2167-05-17 12:36:00.000  2167-05-18 17:03:00.000
# 38236       98755   184156  2167-05-17 12:36:00.000  2167-05-18 17:03:00.000
# 38237       98755   184156  2167-05-17 12:36:00.000  2167-05-18 17:03:00.000
#
#                      deathtime admission_type         admission_location  \
# 0                          NaN      EMERGENCY  TRANSFER FROM HOSP/EXTRAM
# 1                          NaN         URGENT  TRANSFER FROM HOSP/EXTRAM
# 2                          NaN      EMERGENCY  TRANSFER FROM HOSP/EXTRAM
# 3                          NaN      EMERGENCY  TRANSFER FROM HOSP/EXTRAM
# 4                          NaN      EMERGENCY  CLINIC REFERRAL/PREMATURE
# ...                        ...            ...                        ...
# 38233  2172-03-02 08:00:00.000      EMERGENCY  CLINIC REFERRAL/PREMATURE
# 38234                      NaN      EMERGENCY       EMERGENCY ROOM ADMIT
# 38235                      NaN      EMERGENCY       EMERGENCY ROOM ADMIT
# 38236                      NaN      EMERGENCY       EMERGENCY ROOM ADMIT
# 38237                      NaN      EMERGENCY       EMERGENCY ROOM ADMIT
#
#             discharge_location insurance language  ... hospital_expire_flag  \
# 0                         HOME  Medicare      NaN  ...                    0
# 1             HOME HEALTH CARE  Medicare      NaN  ...                    0
# 2                         HOME  Medicare     ENGL  ...                    0
# 3                         HOME  Medicare     ENGL  ...                    0
# 4             HOME HEALTH CARE  Medicare     ENGL  ...                    0
# ...                        ...       ...      ...  ...                  ...
# 38233             DEAD/EXPIRED  Medicare     ENGL  ...                    1
# 38234  LONG TERM CARE HOSPITAL  Medicare     ENGL  ...                    0
# 38235  LONG TERM CARE HOSPITAL  Medicare     ENGL  ...                    0
# 38236  LONG TERM CARE HOSPITAL  Medicare     ENGL  ...                    0
# 38237  LONG TERM CARE HOSPITAL  Medicare     ENGL  ...                    0
#
#       has_chartevents_data                      dob gender seq_num icd9_code  \
# 0                        1  2054-05-04 00:00:00.000      M     3.0      4280
# 1                        1  1872-10-14 00:00:00.000      M     4.0      4281
# 2                        1  1886-07-18 00:00:00.000      M     2.0      4280
# 3                        1  1886-07-18 00:00:00.000      M     2.0      4280
# 4                        1  1886-07-18 00:00:00.000      M     2.0     42822
# ...                    ...                      ...    ...     ...       ...
# 38233                    1  2094-05-01 00:00:00.000      F    29.0      4280
# 38234                    1  2087-03-31 00:00:00.000      F     2.0     42832
# 38235                    1  2087-03-31 00:00:00.000      F     2.0     42832
# 38236                    1  2087-03-31 00:00:00.000      F     4.0      4280
# 38237                    1  2087-03-31 00:00:00.000      F     4.0      4280
#
#        avg_lab_value  cpt_code_count drg_severity ethnicity_group
# 0          38.554538             2.0          NaN   Non-Caucasian
# 1          59.968224             NaN          NaN   Non-Caucasian
# 2          50.406146             2.0          3.0   Non-Caucasian
# 3          50.406146             2.0          NaN   Non-Caucasian
# 4          46.418966             2.0          2.0   Non-Caucasian
# ...              ...             ...          ...             ...
# 38233      45.846425            11.0          NaN   Non-Caucasian
# 38234      51.484063             3.0          2.0   Non-Caucasian
# 38235      51.484063             3.0          NaN   Non-Caucasian
# 38236      51.484063             3.0          2.0   Non-Caucasian
# 38237      51.484063             3.0          NaN   Non-Caucasian
#
# [38238 rows x 26 columns]
# Total rows in cohort: 38238
# Unique subject_ids: 10436
# Number of duplicate subject_id entries: 27802

# %%
hf_cohort['dob'] = pd.to_datetime(hf_cohort['dob'], errors='coerce')
hf_cohort['admittime'] = pd.to_datetime(hf_cohort['admittime'], errors='coerce')
hf_cohort['dischtime'] = pd.to_datetime(hf_cohort['dischtime'], errors='coerce')
hf_cohort['length_of_stay'] = (hf_cohort['dischtime'] - hf_cohort['admittime']).dt.days
hf_cohort = hf_cohort[hf_cohort['length_of_stay'] >= 0]  # Remove any negative values
# Add the admission type directly from the admissions table
hf_cohort['admission_type'] = hf_cohort['admission_type'].astype(str)
# Example: Categorize based on ICD9 codes
print(hf_cohort.isnull().sum())
hf_cohort['icd9_category'] = hf_cohort['icd9_code'].apply(lambda x: 'Cardiovascular' if x in hf_icd9 else 'Other')
hf_cohort['insurance_type'] = hf_cohort['insurance'].astype(str)
hf_cohort['admit_hour'] = hf_cohort['admittime'].dt.hour
hf_cohort['admit_day'] = hf_cohort['admittime'].dt.dayofweek
print(hf_cohort)
# Out:
# subject_id                  0
# hadm_id                     0
# admittime                   0
# dischtime                   0
# deathtime               33373
# admission_type              0
# admission_location          0
# discharge_location          0
# insurance                   0
# language                 7824
# religion                   81
# marital_status            941
# ethnicity                   0
# edregtime               13732
# edouttime               13732
# diagnosis                   6
# hospital_expire_flag        0
# has_chartevents_data        0
# dob                         0
# gender                      0
# seq_num                     0
# icd9_code                   0
# avg_lab_value             143
# cpt_code_count           1683
# drg_severity            21261
# ethnicity_group             0
# length_of_stay              0
# dtype: int64
#        subject_id  hadm_id           admittime           dischtime  \
# 0              26   197661 2126-05-06 15:16:00 2126-05-13 15:00:00
# 1              30   104557 2172-10-14 14:17:00 2172-10-19 14:37:00
# 2              34   115799 2186-07-18 16:46:00 2186-07-20 16:00:00
# 3              34   115799 2186-07-18 16:46:00 2186-07-20 16:00:00
# 4              34   144319 2191-02-23 05:23:00 2191-02-25 20:20:00
# ...           ...      ...                 ...                 ...
# 38233       98753   185764 2172-02-11 21:26:00 2172-03-02 08:00:00
# 38234       98755   184156 2167-05-17 12:36:00 2167-05-18 17:03:00
# 38235       98755   184156 2167-05-17 12:36:00 2167-05-18 17:03:00
# 38236       98755   184156 2167-05-17 12:36:00 2167-05-18 17:03:00
# 38237       98755   184156 2167-05-17 12:36:00 2167-05-18 17:03:00
#
#                      deathtime admission_type         admission_location  \
# 0                          NaN      EMERGENCY  TRANSFER FROM HOSP/EXTRAM
# 1                          NaN         URGENT  TRANSFER FROM HOSP/EXTRAM
# 2                          NaN      EMERGENCY  TRANSFER FROM HOSP/EXTRAM
# 3                          NaN      EMERGENCY  TRANSFER FROM HOSP/EXTRAM
# 4                          NaN      EMERGENCY  CLINIC REFERRAL/PREMATURE
# ...                        ...            ...                        ...
# 38233  2172-03-02 08:00:00.000      EMERGENCY  CLINIC REFERRAL/PREMATURE
# 38234                      NaN      EMERGENCY       EMERGENCY ROOM ADMIT
# 38235                      NaN      EMERGENCY       EMERGENCY ROOM ADMIT
# 38236                      NaN      EMERGENCY       EMERGENCY ROOM ADMIT
# 38237                      NaN      EMERGENCY       EMERGENCY ROOM ADMIT
#
#             discharge_location insurance language  ... icd9_code  \
# 0                         HOME  Medicare      NaN  ...      4280
# 1             HOME HEALTH CARE  Medicare      NaN  ...      4281
# 2                         HOME  Medicare     ENGL  ...      4280
# 3                         HOME  Medicare     ENGL  ...      4280
# 4             HOME HEALTH CARE  Medicare     ENGL  ...     42822
# ...                        ...       ...      ...  ...       ...
# 38233             DEAD/EXPIRED  Medicare     ENGL  ...      4280
# 38234  LONG TERM CARE HOSPITAL  Medicare     ENGL  ...     42832
# 38235  LONG TERM CARE HOSPITAL  Medicare     ENGL  ...     42832
# 38236  LONG TERM CARE HOSPITAL  Medicare     ENGL  ...      4280
# 38237  LONG TERM CARE HOSPITAL  Medicare     ENGL  ...      4280
#
#       avg_lab_value cpt_code_count drg_severity ethnicity_group  \
# 0         38.554538            2.0          NaN   Non-Caucasian
# 1         59.968224            NaN          NaN   Non-Caucasian
# 2         50.406146            2.0          3.0   Non-Caucasian
# 3         50.406146            2.0          NaN   Non-Caucasian
# 4         46.418966            2.0          2.0   Non-Caucasian
# ...             ...            ...          ...             ...
# 38233     45.846425           11.0          NaN   Non-Caucasian
# 38234     51.484063            3.0          2.0   Non-Caucasian
# 38235     51.484063            3.0          NaN   Non-Caucasian
# 38236     51.484063            3.0          2.0   Non-Caucasian
# 38237     51.484063            3.0          NaN   Non-Caucasian
#
#       length_of_stay   icd9_category  insurance_type admit_hour admit_day
# 0                  6  Cardiovascular        Medicare         15         0
# 1                  5  Cardiovascular        Medicare         14         2
# 2                  1  Cardiovascular        Medicare         16         1
# 3                  1  Cardiovascular        Medicare         16         1
# 4                  2  Cardiovascular        Medicare          5         2
# ...              ...             ...             ...        ...       ...
# 38233             19  Cardiovascular        Medicare         21         1
# 38234              1  Cardiovascular        Medicare         12         6
# 38235              1  Cardiovascular        Medicare         12         6
# 38236              1  Cardiovascular        Medicare         12         6
# 38237              1  Cardiovascular        Medicare         12         6
#
# [38213 rows x 31 columns]

# %%
hf_cohort = hf_cohort.dropna(subset=['dob', 'admittime'])
# Remove rows where dob is after admittime (invalid)
hf_cohort = hf_cohort[hf_cohort['dob'] < hf_cohort['admittime']]

# Also remove extremely old people (e.g., born before 1850)
hf_cohort = hf_cohort[hf_cohort['dob'] >= pd.Timestamp('1850-01-01')]

# %%
hf_cohort['readmitted_within_30_days'] = 0
hf_cohort = hf_cohort.sort_values(by=['subject_id']).reset_index(drop=True)


for i in range(1, len(hf_cohort)):
    curr = hf_cohort.iloc[i]
    prev = hf_cohort.iloc[i - 1]
    if (curr['subject_id'] == prev['subject_id'] and
        (curr['admittime'] - prev['dischtime']).days <= 30 and
        (curr['admittime'] - prev['dischtime']).days > 0):
        hf_cohort.at[hf_cohort.index[i - 1], 'readmitted_within_30_days'] = 1

# %%
print(hf_cohort)
# Out:
#        subject_id  hadm_id           admittime           dischtime  \
# 0               3   145834 2101-10-20 19:08:00 2101-10-31 13:58:00
# 1               9   150750 2149-11-09 13:06:00 2149-11-14 10:15:00
# 2              21   109451 2134-09-11 12:17:00 2134-09-24 16:15:00
# 3              21   109451 2134-09-11 12:17:00 2134-09-24 16:15:00
# 4              26   197661 2126-05-06 15:16:00 2126-05-13 15:00:00
# ...           ...      ...                 ...                 ...
# 36386       99991   151118 2184-12-24 08:30:00 2185-01-05 12:15:00
# 36387       99995   137810 2147-02-08 08:00:00 2147-02-11 13:15:00
# 36388       99995   137810 2147-02-08 08:00:00 2147-02-11 13:15:00
# 36389       99995   137810 2147-02-08 08:00:00 2147-02-11 13:15:00
# 36390       99995   137810 2147-02-08 08:00:00 2147-02-11 13:15:00
#
#                      deathtime admission_type         admission_location  \
# 0                          NaN      EMERGENCY       EMERGENCY ROOM ADMIT
# 1      2149-11-14 10:15:00.000      EMERGENCY       EMERGENCY ROOM ADMIT
# 2                          NaN      EMERGENCY       EMERGENCY ROOM ADMIT
# 3                          NaN      EMERGENCY       EMERGENCY ROOM ADMIT
# 4                          NaN      EMERGENCY  TRANSFER FROM HOSP/EXTRAM
# ...                        ...            ...                        ...
# 36386                      NaN       ELECTIVE  PHYS REFERRAL/NORMAL DELI
# 36387                      NaN       ELECTIVE  PHYS REFERRAL/NORMAL DELI
# 36388                      NaN       ELECTIVE  PHYS REFERRAL/NORMAL DELI
# 36389                      NaN       ELECTIVE  PHYS REFERRAL/NORMAL DELI
# 36390                      NaN       ELECTIVE  PHYS REFERRAL/NORMAL DELI
#
#              discharge_location insurance language  ... avg_lab_value  \
# 0                           SNF  Medicare      NaN  ...     59.062004
# 1                  DEAD/EXPIRED  Medicaid      NaN  ...     73.258473
# 2      REHAB/DISTINCT PART HOSP  Medicare      NaN  ...     50.911331
# 3      REHAB/DISTINCT PART HOSP  Medicare      NaN  ...     50.911331
# 4                          HOME  Medicare      NaN  ...     38.554538
# ...                         ...       ...      ...  ...           ...
# 36386                      HOME   Private     ENGL  ...     45.419047
# 36387                      HOME  Medicare     ENGL  ...     48.571817
# 36388                      HOME  Medicare     ENGL  ...     48.571817
# 36389                      HOME  Medicare     ENGL  ...     48.571817
# 36390                      HOME  Medicare     ENGL  ...     48.571817
#
#       cpt_code_count drg_severity ethnicity_group length_of_stay  \
# 0                2.0          NaN   Non-Caucasian             10
# 1                1.0          NaN   Non-Caucasian              4
# 2               10.0          NaN   Non-Caucasian             13
# 3               10.0          4.0   Non-Caucasian             13
# 4                2.0          NaN   Non-Caucasian              6
# ...              ...          ...             ...            ...
# 36386            6.0          NaN   Non-Caucasian             12
# 36387           11.0          2.0   Non-Caucasian              3
# 36388           11.0          NaN   Non-Caucasian              3
# 36389           11.0          NaN   Non-Caucasian              3
# 36390           11.0          2.0   Non-Caucasian              3
#
#         icd9_category  insurance_type  admit_hour admit_day  \
# 0      Cardiovascular        Medicare          19         3
# 1      Cardiovascular        Medicaid          13         6
# 2      Cardiovascular        Medicare          12         5
# 3      Cardiovascular        Medicare          12         5
# 4      Cardiovascular        Medicare          15         0
# ...               ...             ...         ...       ...
# 36386  Cardiovascular         Private           8         4
# 36387  Cardiovascular        Medicare           8         2
# 36388  Cardiovascular        Medicare           8         2
# 36389  Cardiovascular        Medicare           8         2
# 36390  Cardiovascular        Medicare           8         2
#
#       readmitted_within_30_days
# 0                             0
# 1                             0
# 2                             0
# 3                             0
# 4                             0
# ...                         ...
# 36386                         0
# 36387                         0
# 36388                         0
# 36389                         0
# 36390                         0
#
# [36391 rows x 32 columns]

# %%
# age_years = (hf_cohort['admittime'] - hf_cohort['dob']).dt.days / 365.25
# hf_cohort = hf_cohort[age_years < 120]  # optional upper limit
# hf_cohort['age'] = age_years.astype(int)


print("DOB range:", hf_cohort['dob'].min(), "to", hf_cohort['dob'].max())
print("Admit range:", hf_cohort['admittime'].min(), "to", hf_cohort['admittime'].max())
# Remove future or too-far dates to prevent datetime64[ns] overflow
hf_cohort = hf_cohort[hf_cohort['admittime'] <= pd.Timestamp('2200-01-01')]
hf_cohort = hf_cohort[hf_cohort['dob'] <= pd.Timestamp('2200-01-01')]
hf_cohort['age'] = ((hf_cohort['admittime'].values.astype('int64') - 
                     hf_cohort['dob'].values.astype('int64')) 
                    / (1e9 * 60 * 60 * 24 * 365.25)).astype(int)
# Out:
# DOB range: 1850-02-09 00:00:00 to 2198-07-09 00:00:00
# Admit range: 2100-06-28 19:29:00 to 2209-07-14 21:35:00

# %%
print(hf_cohort)
# Out:
#        subject_id  hadm_id           admittime           dischtime  \
# 0               3   145834 2101-10-20 19:08:00 2101-10-31 13:58:00
# 1               9   150750 2149-11-09 13:06:00 2149-11-14 10:15:00
# 2              21   109451 2134-09-11 12:17:00 2134-09-24 16:15:00
# 3              21   109451 2134-09-11 12:17:00 2134-09-24 16:15:00
# 4              26   197661 2126-05-06 15:16:00 2126-05-13 15:00:00
# ...           ...      ...                 ...                 ...
# 36386       99991   151118 2184-12-24 08:30:00 2185-01-05 12:15:00
# 36387       99995   137810 2147-02-08 08:00:00 2147-02-11 13:15:00
# 36388       99995   137810 2147-02-08 08:00:00 2147-02-11 13:15:00
# 36389       99995   137810 2147-02-08 08:00:00 2147-02-11 13:15:00
# 36390       99995   137810 2147-02-08 08:00:00 2147-02-11 13:15:00
#
#                      deathtime admission_type         admission_location  \
# 0                          NaN      EMERGENCY       EMERGENCY ROOM ADMIT
# 1      2149-11-14 10:15:00.000      EMERGENCY       EMERGENCY ROOM ADMIT
# 2                          NaN      EMERGENCY       EMERGENCY ROOM ADMIT
# 3                          NaN      EMERGENCY       EMERGENCY ROOM ADMIT
# 4                          NaN      EMERGENCY  TRANSFER FROM HOSP/EXTRAM
# ...                        ...            ...                        ...
# 36386                      NaN       ELECTIVE  PHYS REFERRAL/NORMAL DELI
# 36387                      NaN       ELECTIVE  PHYS REFERRAL/NORMAL DELI
# 36388                      NaN       ELECTIVE  PHYS REFERRAL/NORMAL DELI
# 36389                      NaN       ELECTIVE  PHYS REFERRAL/NORMAL DELI
# 36390                      NaN       ELECTIVE  PHYS REFERRAL/NORMAL DELI
#
#              discharge_location insurance language  ... cpt_code_count  \
# 0                           SNF  Medicare      NaN  ...            2.0
# 1                  DEAD/EXPIRED  Medicaid      NaN  ...            1.0
# 2      REHAB/DISTINCT PART HOSP  Medicare      NaN  ...           10.0
# 3      REHAB/DISTINCT PART HOSP  Medicare      NaN  ...           10.0
# 4                          HOME  Medicare      NaN  ...            2.0
# ...                         ...       ...      ...  ...            ...
# 36386                      HOME   Private     ENGL  ...            6.0
# 36387                      HOME  Medicare     ENGL  ...           11.0
# 36388                      HOME  Medicare     ENGL  ...           11.0
# 36389                      HOME  Medicare     ENGL  ...           11.0
# 36390                      HOME  Medicare     ENGL  ...           11.0
#
#       drg_severity ethnicity_group length_of_stay   icd9_category  \
# 0              NaN   Non-Caucasian             10  Cardiovascular
# 1              NaN   Non-Caucasian              4  Cardiovascular
# 2              NaN   Non-Caucasian             13  Cardiovascular
# 3              4.0   Non-Caucasian             13  Cardiovascular
# 4              NaN   Non-Caucasian              6  Cardiovascular
# ...            ...             ...            ...             ...
# 36386          NaN   Non-Caucasian             12  Cardiovascular
# 36387          2.0   Non-Caucasian              3  Cardiovascular
# 36388          NaN   Non-Caucasian              3  Cardiovascular
# 36389          NaN   Non-Caucasian              3  Cardiovascular
# 36390          2.0   Non-Caucasian              3  Cardiovascular
#
#       insurance_type  admit_hour  admit_day readmitted_within_30_days age
# 0           Medicare          19          3                         0  76
# 1           Medicaid          13          6                         0  41
# 2           Medicare          12          5                         0  87
# 3           Medicare          12          5                         0  87
# 4           Medicare          15          0                         0  72
# ...              ...         ...        ...                       ...  ..
# 36386        Private           8          4                         0  47
# 36387       Medicare           8          2                         0  88
# 36388       Medicare           8          2                         0  88
# 36389       Medicare           8          2                         0  88
# 36390       Medicare           8          2                         0  88
#
# [35423 rows x 33 columns]

# %%
negative_age = hf_cohort[hf_cohort['age'] <0]
print(negative_age)
# Out:
#        subject_id  hadm_id           admittime           dischtime deathtime  \
# 5              30   104557 2172-10-14 14:17:00 2172-10-19 14:37:00       NaN
# 6              34   115799 2186-07-18 16:46:00 2186-07-20 16:00:00       NaN
# 7              34   144319 2191-02-23 05:23:00 2191-02-25 20:20:00       NaN
# 8              34   144319 2191-02-23 05:23:00 2191-02-25 20:20:00       NaN
# 9              34   144319 2191-02-23 05:23:00 2191-02-25 20:20:00       NaN
# ...           ...      ...                 ...                 ...       ...
# 36120       99186   111707 2183-09-28 19:18:00 2183-10-08 16:15:00       NaN
# 36231       99483   108597 2184-01-11 14:16:00 2184-01-19 16:15:00       NaN
# 36232       99483   108597 2184-01-11 14:16:00 2184-01-19 16:15:00       NaN
# 36233       99483   108597 2184-01-11 14:16:00 2184-01-19 16:15:00       NaN
# 36234       99483   108597 2184-01-11 14:16:00 2184-01-19 16:15:00       NaN
#
#       admission_type         admission_location discharge_location insurance  \
# 5             URGENT  TRANSFER FROM HOSP/EXTRAM   HOME HEALTH CARE  Medicare
# 6          EMERGENCY  TRANSFER FROM HOSP/EXTRAM               HOME  Medicare
# 7          EMERGENCY  CLINIC REFERRAL/PREMATURE   HOME HEALTH CARE  Medicare
# 8          EMERGENCY  CLINIC REFERRAL/PREMATURE   HOME HEALTH CARE  Medicare
# 9          EMERGENCY  CLINIC REFERRAL/PREMATURE   HOME HEALTH CARE  Medicare
# ...              ...                        ...                ...       ...
# 36120       ELECTIVE  PHYS REFERRAL/NORMAL DELI                SNF  Medicare
# 36231       ELECTIVE  PHYS REFERRAL/NORMAL DELI   HOME HEALTH CARE  Medicare
# 36232       ELECTIVE  PHYS REFERRAL/NORMAL DELI   HOME HEALTH CARE  Medicare
# 36233       ELECTIVE  PHYS REFERRAL/NORMAL DELI   HOME HEALTH CARE  Medicare
# 36234       ELECTIVE  PHYS REFERRAL/NORMAL DELI   HOME HEALTH CARE  Medicare
#
#       language  ... cpt_code_count drg_severity ethnicity_group  \
# 5          NaN  ...            NaN          NaN   Non-Caucasian
# 6         ENGL  ...            2.0          3.0   Non-Caucasian
# 7         ENGL  ...            2.0          2.0   Non-Caucasian
# 8         ENGL  ...            2.0          2.0   Non-Caucasian
# 9         ENGL  ...            2.0          NaN   Non-Caucasian
# ...        ...  ...            ...          ...             ...
# 36120     ENGL  ...            9.0          NaN   Non-Caucasian
# 36231     ENGL  ...            4.0          NaN   Non-Caucasian
# 36232     ENGL  ...            4.0          3.0   Non-Caucasian
# 36233     ENGL  ...            4.0          NaN   Non-Caucasian
# 36234     ENGL  ...            4.0          3.0   Non-Caucasian
#
#       length_of_stay   icd9_category insurance_type  admit_hour  admit_day  \
# 5                  5  Cardiovascular       Medicare          14          2
# 6                  1  Cardiovascular       Medicare          16          1
# 7                  2  Cardiovascular       Medicare           5          2
# 8                  2  Cardiovascular       Medicare           5          2
# 9                  2  Cardiovascular       Medicare           5          2
# ...              ...             ...            ...         ...        ...
# 36120              9  Cardiovascular       Medicare          19          6
# 36231              8  Cardiovascular       Medicare          14          6
# 36232              8  Cardiovascular       Medicare          14          6
# 36233              8  Cardiovascular       Medicare          14          6
# 36234              8  Cardiovascular       Medicare          14          6
#
#       readmitted_within_30_days  age
# 5                             0 -284
# 6                             0 -284
# 7                             0 -279
# 8                             0 -279
# 9                             0 -279
# ...                         ...  ...
# 36120                         0 -284
# 36231                         0 -284
# 36232                         0 -284
# 36233                         0 -284
# 36234                         0 -284
#
# [1900 rows x 33 columns]

# %% [markdown]
# # Remove rows with negative age
# hf_cohort = hf_cohort[hf_cohort['age'] >= 0]

# %%
# Remove rows with negative age
hf_cohort = hf_cohort[hf_cohort['age'] >= 0]
# hf_cohort.dropna()

# %%
hf_cohort.to_csv('final_hf_data.csv', index=False)

# %%
re = hf_cohort[hf_cohort['readmitted_within_30_days'] ==1]
print(re)
# Out:
#        subject_id  hadm_id           admittime           dischtime deathtime  \
# 25             68   170467 2173-12-15 16:16:00 2174-01-03 18:30:00       NaN
# 178           356   135591 2132-08-05 00:09:00 2132-08-13 17:41:00       NaN
# 269           518   143946 2109-06-27 04:45:00 2109-06-29 17:00:00       NaN
# 278           530   151499 2119-03-13 16:33:00 2119-04-04 12:00:00       NaN
# 321           631   168097 2124-01-10 21:59:00 2124-01-18 18:25:00       NaN
# ...           ...      ...                 ...                 ...       ...
# 36205       99439   145935 2179-03-18 11:27:00 2179-03-20 18:00:00       NaN
# 36258       99538   194801 2180-02-13 17:46:00 2180-02-26 15:35:00       NaN
# 36281       99562   129689 2183-02-02 15:13:00 2183-02-18 13:28:00       NaN
# 36283       99562   129689 2183-02-02 15:13:00 2183-02-18 13:28:00       NaN
# 36373       99982   151454 2156-11-28 11:56:00 2156-12-08 13:45:00       NaN
#
#       admission_type         admission_location        discharge_location  \
# 25         EMERGENCY       EMERGENCY ROOM ADMIT          HOME HEALTH CARE
# 178        EMERGENCY       EMERGENCY ROOM ADMIT          HOME HEALTH CARE
# 269        EMERGENCY       EMERGENCY ROOM ADMIT                      HOME
# 278        EMERGENCY  TRANSFER FROM HOSP/EXTRAM  REHAB/DISTINCT PART HOSP
# 321        EMERGENCY       EMERGENCY ROOM ADMIT                      HOME
# ...              ...                        ...                       ...
# 36205      EMERGENCY  CLINIC REFERRAL/PREMATURE                       SNF
# 36258      EMERGENCY       EMERGENCY ROOM ADMIT                       SNF
# 36281         URGENT  TRANSFER FROM HOSP/EXTRAM                       SNF
# 36283         URGENT  TRANSFER FROM HOSP/EXTRAM                       SNF
# 36373      EMERGENCY  PHYS REFERRAL/NORMAL DELI          HOME HEALTH CARE
#
#       insurance language  ... cpt_code_count drg_severity ethnicity_group  \
# 25     Medicare      NaN  ...            8.0          4.0   Non-Caucasian
# 178     Private      NaN  ...            4.0          NaN   Non-Caucasian
# 269     Private     ENGL  ...            4.0          3.0   Non-Caucasian
# 278    Medicare      NaN  ...            7.0          NaN   Non-Caucasian
# 321    Medicare     RUSS  ...            8.0          4.0   Non-Caucasian
# ...         ...      ...  ...            ...          ...             ...
# 36205  Medicare     ENGL  ...            4.0          3.0   Non-Caucasian
# 36258  Medicare     ENGL  ...            8.0          NaN   Non-Caucasian
# 36281  Medicare     ENGL  ...           11.0          NaN   Non-Caucasian
# 36283  Medicare     ENGL  ...           11.0          4.0   Non-Caucasian
# 36373  Medicare     ENGL  ...            5.0          3.0   Non-Caucasian
#
#       length_of_stay   icd9_category insurance_type  admit_hour  admit_day  \
# 25                19  Cardiovascular       Medicare          16          2
# 178                8  Cardiovascular        Private           0          1
# 269                2  Cardiovascular        Private           4          3
# 278               21  Cardiovascular       Medicare          16          0
# 321                7  Cardiovascular       Medicare          21          0
# ...              ...             ...            ...         ...        ...
# 36205              2  Cardiovascular       Medicare          11          3
# 36258             12  Cardiovascular       Medicare          17          6
# 36281             15  Cardiovascular       Medicare          15          6
# 36283             15  Cardiovascular       Medicare          15          6
# 36373             10  Cardiovascular       Medicare          11          6
#
#       readmitted_within_30_days age
# 25                            1  41
# 178                           1  58
# 269                           1  46
# 278                           1  79
# 321                           1  74
# ...                         ...  ..
# 36205                         1  84
# 36258                         1  72
# 36281                         1  62
# 36283                         1  62
# 36373                         1  65
#
# [799 rows x 33 columns]
